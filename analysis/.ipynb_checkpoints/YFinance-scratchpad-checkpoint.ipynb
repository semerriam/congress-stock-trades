# %% [markdown]
# # YFinance Scratchpad

# %% [markdown]
# Testing the YFinance Module to understand the type of information one can access for stock tickers

# %% [markdown]
# ----

# %% [markdown]
# ##### Imports

# %%
import yfinance as yf
# Out:
# /Users/sm/.pyenv/versions/3.10.0/lib/python3.10/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('max_seq_item', None)

# %% [markdown]
# -----

# %% [markdown]
# ### Example of looking up individual stock i.e. AFLAC

# %%
aflac = yf.Ticker("AFL")

# %%
# get stock info
aflac.info
# Out:
# {'zip': '31999',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 12447,
#  'longBusinessSummary': 'Aflac Incorporated, through its subsidiaries, provides supplemental health and life insurance products. It operates through two segments, Aflac Japan and Aflac U.S. The Aflac Japan segment offers cancer, medical, nursing care income support, GIFT, and whole and term life insurance products, as well as WAYS and child endowment plans under saving type insurance products in Japan. The Aflac U.S. segment provides cancer, accident, short-term disability, critical illness, hospital indemnity, dental, vision, long-term care and disability, and term and whole life insurance products in the United States. It sells its products through sales associates, brokers, independent corporate agencies, individual agencies, and affiliated corporate agencies. The company was founded in 1955 and is based in Columbus, Georgia.',
#  'city': 'Columbus',
#  'phone': '706 323 3431',
#  'state': 'GA',
# ...

# %% [markdown]
# ##### Identify the sector + industry of a stock

# %%
# 'sector': 'Financial Services'

# %%
aflac.info['sector']
# Out:
# 'Financial Services'

# %%
# 'industry': 'Insurance—Life',

# %%
aflac.info['industry']
# Out:
# 'Insurance—Life'

# %%
aflac.info['longBusinessSummary']
# Out:
# 'Aflac Incorporated, through its subsidiaries, provides supplemental health and life insurance products. It operates through two segments, Aflac Japan and Aflac U.S. The Aflac Japan segment offers cancer, medical, nursing care income support, GIFT, and whole and term life insurance products, as well as WAYS and child endowment plans under saving type insurance products in Japan. The Aflac U.S. segment provides cancer, accident, short-term disability, critical illness, hospital indemnity, dental, vision, long-term care and disability, and term and whole life insurance products in the United States. It sells its products through sales associates, brokers, independent corporate agencies, individual agencies, and affiliated corporate agencies. The company was founded in 1955 and is based in Columbus, Georgia.'

# %% [markdown]
# ----

# %% [markdown]
# ### What companies are considered what under Yahoo's Sectors?

# %% [markdown]
# https://www.yahoo.com/news/sector-industry-breakdown-explained-152427155.html
#
# There are two main methodologies used to classify companies into sectors. The first is known as a production-oriented approach. This method is based on a company’s manufacturing process and the products it creates. In other words it focuses on how a company operates and what it produces.
#
# The second method for classifying companies into sectors is market-oriented and is focused on a company’s target consumer audience. This method isn’t concerned with how companies make their products or what they’re producing. It’s centered on which market segment the company is trying to reach instead.
#
# * North American Industry Classification System (NAICS) — governments in the U.S., Canada and Mexico typically use
# * Global Industry Classification Standard (GICS) https://www.msci.com/our-solutions/indexes/gics

# %% [markdown]
# Yahoo Finance's Sectors:
#
# Communication services: +76.58%
#
# Consumer discretionary: +324.02%
#
# Consumer staples: +136.13%
#
# Energy: + 1.56%
#
# Financials: +154.81%
#
# Healthcare: +224.66%
#
# Industrials: +179.82%
#
# Information technology: +357.78%
#
# Materials: +87.38%
#
# Real estate: +29.18% (3-year return)
#
# Utilities: +114.00%

# %%
google = yf.Ticker("GOOG")
google.info['sector']
# Out:
# 'Communication Services'

# %%
verizon = yf.Ticker("VZ")
verizon.info['sector']
# Out:
# 'Communication Services'

# %%
netflix = yf.Ticker("NFLX")
netflix.info['sector']
# Out:
# 'Communication Services'

# %%
gm = yf.Ticker("GM")
gm.info['sector']
# Out:
# 'Consumer Cyclical'

# %%
macys = yf.Ticker("M")
macys.info['sector']
# Out:
# 'Consumer Cyclical'

# %%
amazon = yf.Ticker("AMZN")
amazon.info['sector']
# Out:
# 'Consumer Cyclical'

# %%
homedepot = yf.Ticker("HD")
homedepot.info['sector']
# Out:
# 'Consumer Cyclical'

# %%
pepsi = yf.Ticker("PEP")
pepsi.info['sector']
# Out:
# 'Consumer Defensive'

# %%
kcc = yf.Ticker("KMB")
kcc.info['sector']
# Out:
# 'Consumer Defensive'

# %%
chevron = yf.Ticker("CVX")
chevron.info['sector']
# Out:
# 'Energy'

# %%
morgan_stanley = yf.Ticker("MS")
morgan_stanley.info['sector']
# Out:
# 'Financial Services'

# %%
aflac = yf.Ticker("AFL")
aflac.info['sector']
# Out:
# 'Financial Services'

# %%
johnson = yf.Ticker("JNJ")
johnson.info['sector']
# Out:
# 'Healthcare'

# %%
lockheed = yf.Ticker("LMT")
lockheed.info['sector']
# Out:
# 'Industrials'

# %%
american_airlines = yf.Ticker("AAL")
american_airlines.info['sector']
# Out:
# 'Industrials'

# %%
threem = yf.Ticker("MMM")
threem.info['sector']
# Out:
# 'Industrials'

# %%
ibm = yf.Ticker("IBM")
ibm.info['sector']
# Out:
# 'Technology'

# %%
sherwin_williams = yf.Ticker("SHW")
sherwin_williams.info['sector']
# Out:
# 'Basic Materials'

# %%
dow = yf.Ticker("DOW")
dow.info['sector']
# Out:
# 'Basic Materials'

# %%
cbre = yf.Ticker("CBRE")
cbre.info['sector']
# Out:
# 'Real Estate'

# %%
con_ed = yf.Ticker("ED")
con_ed.info['sector']
# Out:
# 'Utilities'

# %%
eversource = yf.Ticker("ES")
eversource.info['sector']
# Out:
# 'Utilities'

# %%
data5 = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
# data5['Close']['SPY']

# %%
tickers_test = "SPY AAPL MSFT"

# %%
tickers_test = "SPY AAPL MSFT"

# %%
data6 = yf.download(tickers_test)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# data6

# %%
tickers = yf.Tickers('msft aapl goog')
# ^ returns a named tuple of Ticker objects

# access each ticker using (example)

# %% [markdown]
# ----

# %% [markdown]
# ### What companies are considered what under Yahoo's industry categories?

# %% [markdown]
# https://www.yahoo.com/news/sector-industry-breakdown-explained-152427155.html
#
# There are two main methodologies used to classify companies into sectors. The first is known as a production-oriented approach. This method is based on a company’s manufacturing process and the products it creates. In other words it focuses on how a company operates and what it produces.
#
# The second method for classifying companies into sectors is market-oriented and is focused on a company’s target consumer audience. This method isn’t concerned with how companies make their products or what they’re producing. It’s centered on which market segment the company is trying to reach instead.
#
# * North American Industry Classification System (NAICS) — governments in the U.S., Canada and Mexico typically use
# * Global Industry Classification Standard (GICS) https://www.msci.com/our-solutions/indexes/gics

# %%
df = pd.read_rcsv("..//data//source//gics//GICS_map_2018_edited.csv")

# %%
df
# Out:
#      sector_num                  sector  industry_group_num  \
# 0          10.0                  Energy              1010.0
# 1          10.0                  Energy              1010.0
# 2          10.0                  Energy              1010.0
# 3          10.0                  Energy              1010.0
# 4          10.0                  Energy              1010.0
# 5          10.0                  Energy              1010.0
# 6          10.0                  Energy              1010.0
# 7          15.0               Materials              1510.0
# 8          15.0               Materials              1510.0
# 9          15.0               Materials              1510.0
# 10         15.0               Materials              1510.0
# 11         15.0               Materials              1510.0
# 12         15.0               Materials              1510.0
# 13         15.0               Materials              1510.0
# 14         15.0               Materials              1510.0
# ...

# %%
df['sub_industry']
# Out:
# 0                                                                     Oil & Gas Drilling
# 1                                                         Oil & Gas Equipment & Services
# 2                                                                   Integrated Oil & Gas
# 3                                                     Oil & Gas Exploration & Production
# 4                                                         Oil & Gas Refining & Marketing
# 5                                                     Oil & Gas Storage & Transportation
# 6                                                                Coal & Consumable Fuels
# 7                                                                    Commodity Chemicals
# 8                                                                  Diversified Chemicals
# 9                                                   Fertilizers & Agricultural Chemicals
# ...

# %%
df_sub_industry = df['sub_industry']

# %%
google = yf.Ticker("GOOG")
google.info['industry']
# Out:
# 'Internet Content & Information'

# %%
verizon = yf.Ticker("VZ")
verizon.info['industry']
# Out:
# 'Telecom Services'

# %%
netflix = yf.Ticker("NFLX")
netflix.info['industry']
# Out:
# 'Entertainment'

# %%
gm = yf.Ticker("GM")
gm.info['industry']
# Out:
# 'Auto Manufacturers'

# %%
macys = yf.Ticker("M")
macys.info['industry']
# Out:
# 'Department Stores'

# %%
amazon = yf.Ticker("AMZN")
amazon.info['industry']
# Out:
# 'Internet Retail'

# %%
homedepot = yf.Ticker("HD")
homedepot.info['industry']
# Out:
# 'Home Improvement Retail'

# %%
pepsi = yf.Ticker("PEP")
pepsi.info['industry']
# Out:
# 'Beverages—Non-Alcoholic'

# %%
kcc = yf.Ticker("KMB")
kcc.info['industry']
# Out:
# 'Household & Personal Products'

# %%
chevron = yf.Ticker("CVX")
chevron.info['industry']
# Out:
# 'Oil & Gas Integrated'

# %%
morgan_stanley = yf.Ticker("MS")
morgan_stanley.info['industry']
# Out:
# 'Capital Markets'

# %%
aflac = yf.Ticker("AFL")
aflac.info['industry']
# Out:
# 'Insurance—Life'

# %%
johnson = yf.Ticker("JNJ")
johnson.info['industry']
# Out:
# 'Drug Manufacturers—General'

# %%
lockheed = yf.Ticker("LMT")
lockheed.info['industry']
# Out:
# 'Aerospace & Defense'

# %%
american_airlines = yf.Ticker("AAL")
american_airlines.info['industry']
# Out:
# 'Airlines'

# %%
threem = yf.Ticker("MMM")
threem.info['industry']
# Out:
# 'Conglomerates'

# %%
ibm = yf.Ticker("IBM")
ibm.info['industry']
# Out:
# 'Information Technology Services'

# %%
sherwin_williams = yf.Ticker("SHW")
sherwin_williams.info['industry']
# Out:
# 'Specialty Chemicals'

# %%
dow = yf.Ticker("DOW")
dow.info['industry']
# Out:
# 'Chemicals'

# %%
cbre = yf.Ticker("CBRE")
cbre.info['industry']
# Out:
# 'Real Estate Services'

# %%
con_ed = yf.Ticker("ED")
con_ed.info['industry']
# Out:
# 'Utilities—Regulated Electric'

# %%
eversource = yf.Ticker("ES")
eversource.info['industry']
# Out:
# 'Utilities—Regulated Electric'

# %%
aflac.info['industry']
# Out:
# 'Insurance—Life'

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT"

# %%
import yfinance as yf

tickers = yf.Tickers('msft aapl goog')

print(tickers.tickers['GOOG'].actions)
print(tickers.tickers['AAPL'].history(period="1mo"))
print(tickers.tickers['MSFT'].info)
# Out:
#             Dividends  Stock Splits
# Date
# 2014-03-27        0.0      2.002000
# 2015-04-27        0.0      1.002746
#                   Open        High         Low       Close     Volume  \
# Date
# 2022-02-10  174.139999  175.479996  171.550003  172.119995   90865900
# 2022-02-11  172.330002  173.080002  168.039993  168.639999   98566000
# 2022-02-14  167.369995  169.580002  166.559998  168.880005   86185500
# 2022-02-15  170.970001  172.949997  170.250000  172.789993   62527400
# 2022-02-16  171.850006  173.339996  170.050003  172.550003   61177400
# 2022-02-17  171.029999  171.910004  168.470001  168.880005   69589300
# 2022-02-18  169.820007  170.539993  166.190002  167.300003   82772700
# 2022-02-22  164.979996  166.690002  162.149994  164.320007   91162800
# 2022-02-23  165.539993  166.149994  159.750000  160.070007   90009200
# 2022-02-24  152.580002  162.850006  152.000000  162.740005  141147500
# 2022-02-25  163.839996  165.119995  160.869995  164.850006   91974200
# ...

# %% [markdown]
# ----
